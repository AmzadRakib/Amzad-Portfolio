# %% [markdown]
# <a href="https://colab.research.google.com/github/AmzadRakib/Amzad-Portfolio/blob/main/first_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ('hello world')
print (10-2)
print ('I am checking enviorenment')
# Out:
# hello world
# 8
# I am checking enviorenment
